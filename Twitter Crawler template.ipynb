# %% [markdown]
# ## 1. Install the twitter library in python

# %%
# > !pip install tweepy

# %% [markdown]
# ## 2. Install library for JSON

# %%
# > !pip install simplejson

# %% [markdown]
# ## 3. Install sentiment analysis library

# %%
# Whatever library you use
# > !pip install textblob
# > !python -m textblob.download_corpora lite

# %% [markdown]
# # Streaming tweets and perform some data analysis

# %% [markdown]
# ### Setting up and running a streaming crawler

# %%
import tweepy
import simplejson as json
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
 
#Complete with your keys 
consumer_key = 'Put your consumer key here'
consumer_secret = 'Put your consumer secret here'
access_token = 'Put your access token here'
access_secret = 'Put your acces secret here'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 

class MyListener(StreamListener):
    
    def __init__(self, api=None):
        super(StreamListener, self).__init__()
        self.num_tweets = 0

    def on_data(self, data):
        
        try:
            with open('other.json', 'w') as f:
                # Checks that the language of the tweet is English and, if so, save it.
                if json.loads(data)['lang'] == 'en':
                    f.write(data) # This will store the whole JSON data in the file, you can perform some JSON filters
                    twitter_text = json.loads(data)['text'] # You can also print your tweets here
                    self.num_tweets += 1

                    # Just to limit the number of tweets collected to check the 
                    # program at the beginning, then increase the limit
                if self.num_tweets < 10000: 
                    return True
                else:
                    return False
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True

 
    def on_error(self, status):
        print('Error :', status.place)
        return False
    
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=["davos"]) # Add your keywords and other filters

print('_______ End _______')

# %%
import tweepy
import simplejson as json
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
import datetime
import time
 
#Complete with your keys 
consumer_key = '6MuF4e4cSeDBqYHH2S9aLsbG3'
consumer_secret = '9bTyuSMWCHgKUF73T3IeWSKCOUkUPqC8Hh0xK8r7gI02q3ZWKM'
access_token = '198141183-bfJWLbps5saQVlIUypSVqq25zQ8FGa1lZIeChPXt'
access_secret = 'kwTuELCW2J3odpiVco8mCahwXFGKasY0uuzMZO7X7vTTF'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
# ---------------------------------------------- #
api = tweepy.API(auth)
# ---------------------------------------------- #
#username = sys.argv[1]
startDate = datetime.datetime(2020, 1, 19, 0, 0, 0)
endDate =   datetime.datetime(2020, 1, 23, 0, 0, 0)
# ---------------------------------------------- #
tweets = []
#tmpTweets = api.search("davos", lan="en", until="2020-01-21", count=10000)
'''for tweet in tmpTweets:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        tweets.append(tweet)'''
        
searched_tweets2 = []

cursor = tweepy.Cursor(api.search, "davos", lang="en", until="2020-01-20").items(5000)

while True:
    try:
        tweet = cursor.next()
        searched_tweets2.append(tweet)
    except tweepy.TweepError:
        print('Waiting', len(searched_tweets2))
        time.sleep(60 * 15)
        continue
    except StopIteration:
        break
# Out:
# Waiting 0
# Waiting 2698

# %%
str_tweets1 = [json.dumps(elem._json) for elem in searched_tweets2]

# %%
with open('davos2.json', 'w') as f:
    for tweet in str_tweets1:
        f.write(tweet)
        f.write('\n')

# %% [markdown]
# ### Store the JSON data in a CSV for analysing

# %%
import simplejson as json

# Create the CSV file
with open ("davos2.csv", 'w', encoding ='utf-8') as csv:
    # Write the title of the columns (features) that you want to store in the CSV file
    csv.write('tweet_id,source,user_location,user_id,verified,followers,friends,is_quotation,is_reply,rt_cnt,fav_cnt,text\n') 
    # Copy the data from the JSON file
    with open('davos2.json', 'r', encoding ='utf-8') as jsonfile:
        for tweet in jsonfile: 
            data = json.loads(tweet)
            if data['lang'] != 'en':
                continue
            tweet_id = str(data['id'])
            source = str(data['source'])
            delim_init = source.index(">")+1
            delim_end = source.index("<", delim_init)
            source = source[delim_init:delim_end]
            if data['user']['location']:
                user_location = data['user']['location'].replace('\n', '').replace(",", "")
            else:
                user_location = 'empty'
            user_id = str(data['user']['id'])
            verified = str(data['user']['verified'])
            followers = str(data['user']['followers_count'])
            friends = str(data['user']['friends_count'])
            # Quotation says if tweet is a quotation of another tweet or not
            try:
                if data['quoted_status_id']:
                    is_quotation = str(1)
            except KeyError:
                is_quotation = str(0)
            # Whether the tweet is a reply to another or not
            if data['in_reply_to_status_id']:
                is_reply = str(1)
            else:
                is_reply = str(0)
            retweet_count = str(data['retweet_count'])
            reply_count = "none"#str(0)
            favorite_count = str(data['favorite_count'])

            text = str(data['text'].replace('\n', '').replace(",", ""))
            
            line = ",".join([tweet_id,source,user_location,user_id,verified,followers,friends,is_quotation,is_reply,retweet_count,favorite_count,text])+'\n'
            csv.write(line)

# %%
import string, re, nltk

# %%
punctuation = string.punctuation.replace("#", "").replace("@", "")

# %%
def remove_punctuation(text):
    text = "".join([char for char in text if char not in punctuation])
    text = re.sub('[0-9]+', '', text)
    return text

# %%
def tokenization (text):
    text = re.split(' ', text)
    return text

# %%
def remove_stopwords(text):
    stopwords = nltk.corpus.stopwords.words('english')
    other = ['rt', 'yr', 'year', 'old', 'http', 'https', 'davos']
    stopwords.extend(other)
    text = [word for word in text if not (word.startswith("@") or word.startswith("#"))]
    text = [word for word in text if word not in stopwords]
    return " ".join(text)

# %% [markdown]
# ### Load the previous CSV into pandas

# %%
import pandas as pd
tweets1 = pd.read_csv('davos2.csv', index_col=0, encoding='utf-8', delimiter=',')
tweets2 = pd.read_csv('davos3.csv', index_col=0, encoding='utf-8', delimiter=',')
tweets = pd.concat([tweets1, tweets2])
tweets['text_punct'] = tweets['text'].apply(lambda x: remove_punctuation(x))
tweets['text_token'] = tweets['text_punct'].apply(lambda x: tokenization(x.lower()))
tweets['text_clean'] = tweets['text_token'].apply(lambda x: remove_stopwords(x))
tweets['popularity'] = tweets['rt_cnt'] + tweets['fav_cnt']
tweets['text_polarity'] =  tweets['text_punct'].apply(lambda x: TextBlob(x).sentiment.polarity)
tweets['text_subjectivity'] =  tweets['text_punct'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
tweets.head(10)
# Out:
#                                   source              user_location  \
# tweet_id
# 1219046880933502976  Twitter for Android                 stuffistan
# 1219046869352865793  Twitter for Android        Vancouver BC canada
# 1219046851661455360   Twitter for iPhone                      empty
# 1219046847127412738   Twitter for iPhone  Galway * Oslo * Worldwide
# 1219046778986692616      Twitter Web App              Madrid España
# 1219046753799942144      Twitter Web App                    Tampere
# 1219046749173452800  Twitter for Android                  PNW / NYC
# 1219046744836755456      Twitter Web App               Havertown Pa
# 1219046736863420416   Twitter for iPhone            Cambridge Mass.
# 1219046731423326209  Twitter for Android    South Yorkshire England
#
#                                  user_id  verified  followers  friends  \
# tweet_id
# 1219046880933502976           2412715069     False         66     1521
# 1219046869352865793  1062311268122411013     False         96      443
# 1219046851661455360            246993396     False       2779     2234
# 1219046847127412738            225797064     False       2007     5001
# 1219046778986692616            733824560     False       6374     5527
# 1219046753799942144             71367033     False        247     1078
# 1219046749173452800  1054959943445594113     False         38      258
# 1219046744836755456   832267802090291200     False         93     1333
# 1219046736863420416                36623      True      39487     2936
# 1219046731423326209            120479248     False        238      578
#
#                      is_quotation  is_reply  rt_cnt  fav_cnt  \
# tweet_id
# 1219046880933502976             0         0       7        0
# 1219046869352865793             0         0      89        0
# 1219046851661455360             0         0       4        0
# 1219046847127412738             0         0      12        0
# 1219046778986692616             0         0     166        0
# 1219046753799942144             0         0       0        9
# 1219046749173452800             0         0     206        0
# 1219046744836755456             0         0     199        0
# 1219046736863420416             0         0      13        0
# 1219046731423326209             0         0     118        0
#
#                                                                   text  \
# tweet_id
# 1219046880933502976  RT @adam_tooze: Trade war on? Trade war off? W...
# 1219046869352865793  RT @AminaJMohammed: What color is your climate...
# 1219046851661455360  RT @CaracasChron: On Sunday it’s been confirme...
# 1219046847127412738  RT @CEPIvaccines: “Infectious disease is a rem...
# 1219046778986692616  RT @PattyLaya: Guaido plans to attend the Worl...
# 1219046753799942144  We have a great Prime Minister 🎉!   #sannamari...
# 1219046749173452800  RT @IPBES: "We all rely on nature and we all t...
# 1219046744836755456  RT @agearan: Trump will rub shoulders w/ world...
# 1219046736863420416  RT @zseward: Just a quarter of Davos delegates...
# 1219046731423326209  RT @KGeorgieva: As world leaders gather in Dav...
#
#                                                             text_punct  \
# tweet_id
# 1219046880933502976  RT @adamtooze Trade war on Trade war off What ...
# 1219046869352865793  RT @AminaJMohammed What color is your climate ...
# 1219046851661455360  RT @CaracasChron On Sunday it’s been confirmed...
# 1219046847127412738  RT @CEPIvaccines “Infectious disease is a remi...
# 1219046778986692616  RT @PattyLaya Guaido plans to attend the World...
# 1219046753799942144  We have a great Prime Minister 🎉   #sannamarin...
# 1219046749173452800  RT @IPBES We all rely on nature and we all tak...
# 1219046744836755456  RT @agearan Trump will rub shoulders w world l...
# 1219046736863420416  RT @zseward Just a quarter of Davos delegates ...
# 1219046731423326209  RT @KGeorgieva As world leaders gather in Davo...
#
#                                                             text_token  \
# tweet_id
# 1219046880933502976  [rt, @adamtooze, trade, war, on, trade, war, o...
# 1219046869352865793  [rt, @aminajmohammed, what, color, is, your, c...
# 1219046851661455360  [rt, @caracaschron, on, sunday, it’s, been, co...
# 1219046847127412738  [rt, @cepivaccines, “infectious, disease, is, ...
# 1219046778986692616  [rt, @pattylaya, guaido, plans, to, attend, th...
# 1219046753799942144  [we, have, a, great, prime, minister, 🎉, , , #...
# 1219046749173452800  [rt, @ipbes, we, all, rely, on, nature, and, w...
# 1219046744836755456  [rt, @agearan, trump, will, rub, shoulders, w,...
# 1219046736863420416  [rt, @zseward, just, a, quarter, of, davos, de...
# 1219046731423326209  [rt, @kgeorgieva, as, world, leaders, gather, ...
#
#                                                             text_clean  \
# tweet_id
# 1219046880933502976  trade war trade war make trump tantrums piece ...
# 1219046869352865793  color climate leadership  it’s time go green b...
# 1219046851661455360  sunday it’s confirmed traveled colombia start ...
# 1219046847127412738  “infectious disease reminder interconnected st...
# 1219046778986692616  guaido plans attend world economic forum inter...
# 1219046753799942144  great prime minister 🎉   finland’s sanna marin...
# 1219046749173452800  rely nature take grantedahead new report produ...
# 1219046744836755456  trump rub shoulders w world leaders major euro...
# 1219046736863420416  quarter delegates women yet two white dudes na...
# 1219046731423326209  world leaders gather week hope find time read ...
#
#                      popularity  text_polarity  text_subjectivity
# tweet_id
# 1219046880933502976           7       0.000000           0.000000
# 1219046869352865793          89       0.016667           0.383333
# 1219046851661455360           4       0.200000           0.500000
# 1219046847127412738          12       0.000000           0.000000
# 1219046778986692616         166       0.100000           0.150000
# 1219046753799942144           9       0.400000           0.458333
# 1219046749173452800         206       0.136364           0.454545
# 1219046744836755456         199      -0.084375           0.300000
# 1219046736863420416          13       0.000000           0.000000
# 1219046731423326209         118       0.136364           0.454545

# %% [markdown]
# ### Analysing the polarity of the tweets

# %%
avg_polarity = tweets['text_polarity'].mean()
avg_subjectivity = tweets['text_subjectivity'].mean()
avg_polarity, avg_subjectivity
# Out:
# (0.0908217847654304, 0.26446051022370803)

# %%
s = ' '.join(tweets['text_clean'].to_list())

# %% [markdown]
# ### Generating a wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
 
# Create a list of word
text = s
# Create the wordcloud object
wordcloud = WordCloud(width=1024, height=1024, margin=0).generate(text)
 
# Display the generated image:
plt.figure(figsize=(14, 14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ## Your own analysis

# %%
s = ' '.join([elem for elem in tweets['user_location'].to_list() if elem != 'empty'])
text = s
# Create the wordcloud object
wordcloud = WordCloud(width=1024, height=1024, margin=0).generate(text)
 
# Display the generated image:
plt.figure(figsize=(14, 14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import warnings
warnings.filterwarnings("ignore")
fig, ax = plt.subplots(figsize=(20,10))
tweets['source'].value_counts().plot(ax=ax, kind='bar')
plt.ylabel("Frequency", color='black')
plt.xlabel("Source app", color='black')
plt.title('Source app by number of users', color='blue', fontsize=24)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
tweets['source'].value_counts()[tweets['source'].value_counts() > 10].plot(ax=ax, kind='bar')
plt.ylabel("Frequency", color='black')
plt.xlabel("Source app", color='black')
plt.ylabel("Frequency", color='black')
plt.xlabel("Source app", color='black')
plt.title('Source app by number of users (zoom-in)', color='blue', fontsize=24)
plt.show()

# %% [markdown]
# ## Histograms followers

# %%
fig, ax = plt.subplots(figsize=(20,10))
maxi = 10000
tweets['followers'].plot.hist(bins=40, range=(0,maxi))
plt.ylabel("Number of users", color='black')
plt.xlabel("Followers", color='black')
plt.title("Ranges of number of followers and number of users", color='blue', fontsize=24)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
maxi = 10000
tweets['friends'].plot.hist(bins=40, range=(0,maxi))
plt.ylabel("Number of users", color='black')
plt.xlabel("Friends", color='black')
plt.title("Ranges of number of friends and number of users", color='blue', fontsize=24)
plt.show()

# %%
verified_unique = tweets[['user_id','verified']].drop_duplicates()['verified']

fig, ax = plt.subplots(figsize=(8,8))
verified_unique.value_counts().plot(ax=ax, kind='bar')
plt.ylabel("Frequency", color='black')
plt.xlabel("Verified", color='black')
plt.title("Number of verfied users", color='blue', fontsize=18)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
maxi = 10000
tweets['text_polarity'].plot.hist(bins=16, range=(-1,1))
plt.ylabel("Number of users", color='black')
plt.xlabel("Polarity level", color='black')
plt.title("Text Polarity", color='blue', fontsize=24)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
maxi = 10000
tweets['text_subjectivity'].plot.hist(bins=16, range=(0,1))
plt.ylabel("Number of users", color='black')
plt.xlabel("Subjectivity level", color='black')
plt.title("Text Subjectivity", color='blue', fontsize=24)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
maxi = 6000
tweets['popularity'].plot.hist(bins=50, range=(0,maxi))
plt.ylabel("Number of users", color='black')
plt.xlabel("Popularity level", color='black')
plt.title("Tweet Popularity", color='blue', fontsize=24)
plt.show()
